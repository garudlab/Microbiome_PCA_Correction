# %%
import sys
import pandas as pd
import numpy as np
import random
from collections import Counter
import scipy as sp
from scipy import stats, optimize, interpolate
import statsmodels.api as sm
import statsmodels as sm
random.seed(0)
from functools import reduce
import os
import pickle

# %%
main_dir ="/u/home/b/briscoel/project-halperin/MicroBatch/data/"
script_folder= "/u/home/b/briscoel/project-halperin/MicroBatch/RevisionSequence/"
local = True

sys.argv = [ "Thomasr_complete_otu","rel",""]

if local:
    main_dir = "/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/"
    script_folder = "/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/RevisionSequence/"

folder = sys.argv[0] # "AGPr_max_k5" #"AGPr_complete_otu" 
trans = sys.argv[1] #"rel"

data_dir = main_dir + folder + "/"


out_dir = data_dir + "titration/"
out_dir2 = data_dir + "titration_archive/"
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)
    print("created folder : ", out_dir)

else:
    print(out_dir, "folder already exists.")
# Out:
# /Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/Thomasr_complete_otu/titration/ folder already exists.

# %%
metadata_table = pd.read_csv(data_dir + "metadata.txt", delimiter = "\t",header=0)



if folder == "Gibbonsr_complete_otu":
    phenotype ='bin_crc_normal'
    batch="study"
    metadata_table[phenotype] = [1 if lab=='CRC' else 0 for lab in metadata_table['bin_crc_normal']]
elif folder == "Thomasr_complete_otu":
    phenotype ='bin_crc_normal'
    batch="dataset_name"
all_studies = list(Counter(metadata_table[batch]))

# %%
#all_control_samples = list(metadata_table[metadata_table['bin_crc_normal'] == 0].index)
#all_case_samples = list(metadata_table[metadata_table['bin_crc_normal'] == 1].index)
#feature_table_presence = feature_table  > 0  
# control_presence_proportion = (feature_table_presence[all_control_samples].sum(axis =1))/len(all_control_samples)
# case_presence_proportion = (feature_table_presence[all_case_samples].sum(axis =1))/len(all_case_samples)
# ## FILTER FOR 1/3 in at least case OR control : not using for now
# prevalence_filter = np.array(control_presence_proportion > 0.33) | np.array(case_presence_proportion > 0.33)

# %%
orig_feature_table = pd.read_csv(data_dir  +"feature_table_" + trans + ".txt" ,delimiter = "\t",header=0)
df_biomarkers = pd.DataFrame(index = orig_feature_table.index,columns = all_studies)

# %%
def titration(d1, d2 ,metadata_table,fractions,corrections):
    random.seed(0)
    control_metadata1 = metadata_table[(metadata_table[phenotype] == 0 ) & (metadata_table[batch] ==  d1) ]
    case_metadata1 = metadata_table[(metadata_table[phenotype] == 1) & (metadata_table[batch] ==  d1)]

    control_metadata2 = metadata_table[(metadata_table[phenotype] == 0 ) & (metadata_table[batch] ==  d2) ]
    case_metadata2 = metadata_table[(metadata_table[phenotype] == 1) & (metadata_table[batch] ==  d2)]

    control_samples_d1 = list(control_metadata1.index)
    case_samples_d1 = list(case_metadata1.index)

    control_samples_d2 = list(control_metadata2.index)
    case_samples_d2 = list(case_metadata2.index)

    min_sample_size = min([len(control_samples_d1),len(case_samples_d1),len(control_samples_d2),len(case_samples_d2)])
    
    control_samples_d1 = random.sample(control_samples_d1,min_sample_size)
    case_samples_d1 = random.sample(case_samples_d1,min_sample_size)
    control_samples_d2 = random.sample(control_samples_d2,min_sample_size)
    case_samples_d2 = random.sample(case_samples_d2,min_sample_size)
    
    
    replicate_titrate_rel_names = {}
    replicate_titrate_rel_fdr = {}



    
    for correction in corrections:
        print(correction)
        replicate_titrate_rel_names[correction] = dict()
        replicate_titrate_rel_fdr[correction] = dict()
        if correction == "nocorrection":
            feature_table = pd.read_csv(data_dir  + "feature_table_" + trans + ".txt" ,delimiter = "\t",header=0)
        elif correction in ["logcpm_combat" , "logcpm_limma" ,  "logcpm_bmc" ,    "vst_combat"  ,   "vst_limma" ,     "vst_bmc" ,
                                      "rel_clr_combat", "rel_clr_limma", "rel_clr_bmc"  ]:
            feature_table = pd.read_csv(data_dir  + "feature_table_" + correction + ".txt" ,delimiter = "\t",header=0)
       
        else:
            feature_table = pd.read_csv(data_dir  +"feature_table_" + trans + "_" + correction + ".txt" ,delimiter = "\t",header=0)

        for n in range(num_replicates):
            print(n)
            titrate_rel_names = {}
            titrate_rel_fdr = {}
            for f in fractions:
                pvals = []           
                case_samples = case_samples_d1
                control_samples = random.sample(control_samples_d1,int((1-f) * min_sample_size)) + random.sample(control_samples_d2, int(f * min_sample_size))
                feature_table_titrate_control = feature_table[control_samples ]
                feature_table_titrate_case = feature_table[case_samples ]
                
                feature_table_titrate_control_prev = (feature_table_titrate_control > 1e-4)
                feature_table_titrate_case_prev = (feature_table_titrate_case > 1e-4)

                # for each taxa
                tax_names = []
                for tax in range(feature_table_titrate_case.shape[0]):
                    
                    if feature_table_titrate_control_prev.iloc[tax,:].astype(bool).sum()/float(feature_table_titrate_control.shape[1]) >= 1/3.0 or feature_table_titrate_case_prev.iloc[tax,:].astype(bool).sum()/float(feature_table_titrate_case.shape[1]) >= 1/3.0:
                        pvals.append(sp.stats.ranksums(feature_table_titrate_control.iloc[tax,:],feature_table_titrate_case.iloc[tax,:])[1])
                        tax_names.append(feature_table_titrate_case.index[tax])
                    #else:
                        #pvals.append(1)
#                     if (feature_table_titrate_control.iloc[tax,:] > -2).astype(bool).sum()/float(feature_table_titrate_control.shape[1]) >= 1/3.0 or (feature_table_titrate_case.iloc[tax,:] > -2).astype(bool).sum()/float(feature_table_titrate_case.shape[1]) >= 1/3.0:
#                         pvals.append(sp.stats.ranksums(feature_table_titrate_control.iloc[tax,:],feature_table_titrate_case.iloc[tax,:])[1])
#                     else:
#                         pvals.append(1)

                pvals = np.array(pvals)
                if(len(pvals) > 0):
    
                    pvals_fdr = sm.sandbox.stats.multicomp.multipletests(np.array(pvals),alpha=0.05,method='fdr_bh')[1]
                else:
                    pvals_fdr = []
                names = []
                fdr = []

                for j in range(len(pvals_fdr)):
                    if pvals_fdr[j] <= 0.05:
                        names.append(tax_names[j])
                        fdr.append(pvals_fdr[j])


                titrate_rel_names[f] = names
                titrate_rel_fdr[f] = fdr



            replicate_titrate_rel_names[correction][n] = titrate_rel_names
            replicate_titrate_rel_fdr[correction][n] = titrate_rel_fdr
            
    plot_titrate_rel_names = dict()
    for correction in corrections:
        plot_titrate_rel_names[correction] = dict()
        plot_titrate_rel_names[correction]["fraction"]  = []
        plot_titrate_rel_names[correction]["num_sig"]  = []
        for f in fractions:
            plot_titrate_rel_names[correction]["fraction"].append(f)
            num_sig = []
            for n in range(num_replicates):
                num_sig.append(len(replicate_titrate_rel_fdr[correction][n][f]))

            # calculate mean number of significant OTUs
            plot_titrate_rel_names[correction]["num_sig"].append(np.mean(num_sig))
    return(plot_titrate_rel_names,replicate_titrate_rel_names)

# %%
# 
# fractions = [0,.25 ,  1] # fraction of controls replaced
# corrections = ["nocorrection","percentilenorm"] 
# titrate1,biomarkers1 = titration(d1 = d11, d2 = d21, 
#                                    metadata_table = metadata_table,fractions = fractions,corrections = corrections)

# %%
num_replicates= 5

fractions = [0,.25 , .50, 0.75, 1] # fraction of controls replaced

version = "alternate"
if version == "original":
    corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","clr_pca3counts","clr_pca4counts","clr","vsd","logCPM"] #,]
else:
    corrections = ["nocorrection","logcpm_combat" , "logcpm_limma" ,  "logcpm_bmc" ,    "vst_combat"  ,   "vst_limma" ,     "vst_bmc" ,
                                      "rel_clr_combat", "rel_clr_limma", "rel_clr_bmc"]

    # corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","clr_pca3counts","clr_pca1counts"] #,]
corrections_copy = corrections

for s in range(len(all_studies)):
    for s2 in range((s+1),len(all_studies)):
        d11 = all_studies[s] # 'HanniganGD_2017'
        d21 = all_studies[s2] #'YuJ_2015'
        d12 = all_studies[s2] #'YuJ_2015'
        d22 = all_studies[s] #'HanniganGD_2017'

        
        titrate1,biomarkers1 = titration(d1 = d11, d2 = d21, 
                                   metadata_table = metadata_table,fractions = fractions,corrections = corrections)
        
#         biomarker_list_list = []
#         for i in range(num_replicates):
#             biomarker_list_list.append(biomarkers1["clr_pcacounts"][i][0])

#         agreement_onedataset = list(reduce(set.intersection, [set(item) for item in biomarker_list_list ]))
#         df_biomarkers.loc[agreement_onedataset,d11] = 1
        
#         df_biomarkers.to_csv( "DF_biomarkers.csv",index=True)
        
#         print("starting titrate 2")

        titrate2,biomarkers2 = titration(d1 = d12 , d2 = d22, 
                                   metadata_table = metadata_table,fractions = fractions,corrections = corrections)
        
        
        ## SAVE TO PICKLE
        print("Saving pickles")
        with open(out_dir  + 'titrate_' + d11 + '_' + d21 + '.pkl', 'wb') as handle:
            pickle.dump(titrate1, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with open(out_dir  + 'titrate_' + d12 + '_' + d22 + '.pkl', 'wb') as handle:
            pickle.dump(titrate2, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with open(out_dir  + 'titrate_biomarkers_' + d11 + '_' + d21 + '.pkl', 'wb') as handle:
            pickle.dump(biomarkers1, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with open(out_dir  + 'titrate_biomarkers_' + d12 + '_' + d22 + '.pkl', 'wb') as handle:
            pickle.dump(biomarkers2, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
        
        #corrections = ["nocorrection","percentilenorm","clr_pcacounts"] 
        corrections = corrections_copy

        import matplotlib.pyplot as plt

        fig, (ax1,ax2) = plt.subplots(1,2,sharex=True, sharey=True)  

        line_widths = [3.5,3.5,3.5,3.5,3.5,4.5,4.5,4.5,4.5,4.5,4.5]
        line_styles = ['-','-',"-",":",":",":","--","--","--",'-.','-.']

        for c in range(len(corrections)):
            ax1.plot(titrate1[corrections[c]]["fraction"],titrate1[corrections[c]]["num_sig"],
                     label = corrections[c],linewidth=line_widths[c],linestyle = line_styles[c])
        d1 = d11
        d2 = d21
        ax1.set_title(d1 + ' > titrate ' + d2 ,fontsize=9)

        for c in range(len(corrections)):
            ax2.plot(titrate2[corrections[c]]["fraction"],titrate2[corrections[c]]["num_sig"],
                     label = corrections[c],linewidth=line_widths[c],linestyle = line_styles[c])

        d2 = d22
        d1 = d12 
        ax2.set_title(d1 + ' > titrate ' + d2 ,fontsize=9)

        ax1.locator_params(nbins=5, axis='y')
        ax2.legend(loc=2,prop={'size':10})
        #fig.text(0.001, 0.5, 'number of significant OTUs (q <= 0.05)', va='center', rotation='vertical',fontsize=12)
        fig.text(0.5, 0.003, 'fraction of control samples from another study', ha='center',fontsize=12)
        ax1.set_ylabel('number of significant OTUs (q <= 0.05)')
        plt.tight_layout()
        #plt.show()
        
        plt.savefig(out_dir  + 'titrate_' + d11 + '_' + d21 + '.pdf',dpi=300,format='pdf')
# Out:
# nocorrection
# 0
# 1
# 2
# 3
# 4
# logcpm_combat
# 0
# 1
# 2
# 3
# 4
# logcpm_limma
# 0
# 1
# 2
# 3
# 4
# logcpm_bmc
# 0
# 1
# 2
# 3
# 4
# vst_combat
# 0
# 1
# 2
# 3
# 4
# vst_limma
# 0
# 1
# 2
# 3
# 4
# vst_bmc
# 0
# 1
# 2
# 3
# 4
# rel_clr_combat
# 0
# 1
# 2
# 3
# 4
# rel_clr_limma
# 0
# 1
# 2
# 3
# 4
# rel_clr_bmc
# 0
# 1
# 2
# 3
# 4
# nocorrection
# 0
# 1
# 2
# 3
# 4
# logcpm_combat
# 0
# 1
# 2
# 3
# 4
# logcpm_limma
# 0
# 1
# 2
# 3
# 4
# logcpm_bmc
# 0
# 1
# 2
# 3
# 4
# vst_combat
# 0
# 1
# 2
# 3
# 4
# vst_limma
# 0
# 1
# 2
# 3
# 4
# vst_bmc
# 0
# 1
# 2
# 3
# 4
# rel_clr_combat
# 0
# 1
# 2
# 3
# 4
# rel_clr_limma
# 0
# 1
# 2
# 3
# 4
# rel_clr_bmc
# 0
# 1
# 2
# 3
# 4
# Saving pickles
# nocorrection
# 0
# 1
# 2
# 3
# 4
# logcpm_combat
# 0
# 1
# 2
# 3
# 4
# logcpm_limma
# 0
# 1
# 2
# 3
# 4
# logcpm_bmc
# 0
# 1
# 2
# 3
# 4
# vst_combat
# 0
# 1
# 2
# 3
# 4
# vst_limma
# 0
# 1
# 2
# 3
# 4
# vst_bmc
# 0
# 1
# 2
# 3
# 4
# rel_clr_combat
# 0
# 1
# 2
# 3
# 4
# rel_clr_limma
# 0
# 1
# 2
# 3
# 4
# rel_clr_bmc
# 0
# 1
# 2
# 3
# 4
# nocorrection
# 0
# 1
# 2
# 3
# 4
# logcpm_combat
# 0
# 1
# 2
# 3
# 4
# logcpm_limma
# 0
# 1
# 2
# 3
# 4
# logcpm_limma
# 0
# 1
# 2
# 3
# 4
# logcpm_bmc
# 0
# 1
# 2
# 3
# 4
# vst_combat
# 0
# 1
# 2
# 3
# 4
# vst_limma
# 0
# 1
# 2
# 3
# 4
# vst_bmc
# 0
# 1
# 2
# 3
# 4
# rel_clr_combat
# 0
# 1
# 2
# 3
# 4
# rel_clr_limma
# 0
# 1
# 2
# 3
# 4
# rel_clr_bmc
# 0
# 1
# 2
# 3
# 4
# Saving pickles
# /Users/leahbriscoe/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
print(all_studies)
for s in range(len(all_studies)):
    for s2 in range((s+1),len(all_studies)):
        print(all_studies[s] + " " + all_studies[s2])
        print(all_studies[s2] + " " + all_studies[s])
# Out:
# ['FengQ_2015', 'HanniganGD_2017', 'ThomasAM_2018a', 'ThomasAM_2018b', 'VogtmannE_2016', 'YuJ_2015', 'ZellerG_2014']
# FengQ_2015 HanniganGD_2017
# HanniganGD_2017 FengQ_2015
# FengQ_2015 ThomasAM_2018a
# ThomasAM_2018a FengQ_2015
# FengQ_2015 ThomasAM_2018b
# ThomasAM_2018b FengQ_2015
# FengQ_2015 VogtmannE_2016
# VogtmannE_2016 FengQ_2015
# FengQ_2015 YuJ_2015
# YuJ_2015 FengQ_2015
# FengQ_2015 ZellerG_2014
# ZellerG_2014 FengQ_2015
# HanniganGD_2017 ThomasAM_2018a
# ThomasAM_2018a HanniganGD_2017
# HanniganGD_2017 ThomasAM_2018b
# ThomasAM_2018b HanniganGD_2017
# HanniganGD_2017 VogtmannE_2016
# VogtmannE_2016 HanniganGD_2017
# HanniganGD_2017 YuJ_2015
# YuJ_2015 HanniganGD_2017
# HanniganGD_2017 ZellerG_2014
# ZellerG_2014 HanniganGD_2017
# ThomasAM_2018a ThomasAM_2018b
# ThomasAM_2018b ThomasAM_2018a
# ThomasAM_2018a VogtmannE_2016
# VogtmannE_2016 ThomasAM_2018a
# ThomasAM_2018a YuJ_2015
# YuJ_2015 ThomasAM_2018a
# ThomasAM_2018a ZellerG_2014
# ZellerG_2014 ThomasAM_2018a
# ThomasAM_2018b VogtmannE_2016
# VogtmannE_2016 ThomasAM_2018b
# ThomasAM_2018b YuJ_2015
# YuJ_2015 ThomasAM_2018b
# ThomasAM_2018b ZellerG_2014
# ZellerG_2014 ThomasAM_2018b
# VogtmannE_2016 YuJ_2015
# YuJ_2015 VogtmannE_2016
# VogtmannE_2016 ZellerG_2014
# ZellerG_2014 VogtmannE_2016
# YuJ_2015 ZellerG_2014
# ZellerG_2014 YuJ_2015

# %%
average_associations = dict()
#corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","clr","vsd","logCPM","clr_pca3counts","clr_pca4counts"]
props = [0,.25 , .50, 0.75, 1]
fractions = [0,.25 , .50, 0.75, 1]
for corr in corrections:
    
    average_associations[corr] = dict()
    for i in props:
        average_associations[corr][i] = []

# %%
average_associations
# Out:
# {'nocorrection': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'logcpm_combat': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'logcpm_limma': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'logcpm_bmc': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'vst_combat': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'vst_limma': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'vst_bmc': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'rel_clr_combat': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'rel_clr_limma': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []},
#  'rel_clr_bmc': {0: [], 0.25: [], 0.5: [], 0.75: [], 1: []}}

# %%
for s in range(len(all_studies)):
    for s2 in range((s+1),len(all_studies)):
        d11 = all_studies[s] # 'HanniganGD_2017'
        d21 = all_studies[s2] #'YuJ_2015'
        d12 = all_studies[s2] #'YuJ_2015'
        d22 = all_studies[s] #'HanniganGD_2017'


        with open(out_dir  + 'titrate_biomarkers_' + d11 + '_' + d21 + '.pkl', 'rb') as handle:
                titration1 = pickle.load(handle)            

        with open(out_dir  + 'titrate_biomarkers_' + d12 + '_' + d22 + '.pkl', 'rb') as handle:
                titration2 = pickle.load(handle)
        for corr in corrections:
            for it in [0,1,2,3,4]:
                for i in props:

                    average_associations[corr][i].append(len(titration1[corr][it][i]))
                    average_associations[corr][i].append(len(titration2[corr][it][i]))

# %%
methods = corrections
np_stats = pd.DataFrame(index = methods, columns = props)
for corr in methods:
    for i in props:
        np_stats.loc[corr,i] = np.mean(average_associations[corr][i])

# %%
np_stats
# Out:
#                     0.00      0.25     0.50     0.75     1.00
# nocorrection     4.40476   3.92381  12.3714  28.6429  44.6905
# logcpm_combat   0.904762  0.971429  1.20476  1.04286  1.07143
# logcpm_limma    0.904762   1.28095  1.56667   1.7619  2.33333
# logcpm_bmc      0.904762   1.20952  1.41905  1.87143  2.33333
# vst_combat       4.40476   4.47619  8.90952  27.0857  46.6667
# vst_limma        4.28571   5.64286   12.419  34.3619  56.9286
# vst_bmc          4.42857   5.86667  7.98095  13.0381  27.3333
# rel_clr_combat    8.7619       6.3  6.98095  15.0714  27.7857
# rel_clr_limma          6    6.6619  9.09524  22.1286  37.0952
# rel_clr_bmc      178.238   161.133   139.79  188.795  257.405

# %%
titrate1["nocorrection"]['fraction']

# %%
plot = True
num_replicates = 5
fractions = [0,.25 , .50, 0.75, 1] # fraction of controls replaced

if plot:
    #corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","clr","vsd","logCPM","clr_pca3counts","clr_pca4counts"]
#     corrections_pretty =  ["Uncorrected","Percentile Norm","DCC","ComBat","limma","BMC","CLR","VST","logCPM","Fixed PCA Corr.","Tuned PCA Corr."]
#     colors = ['#e32f27',"#b800a5","#1ad93d",'#FF9300','#b8ba1c','#fdd0a2',"#9A33FF","#F133FF","#3341FF","#72C1FC","#0093FF"]
#     line_widths = [3.5,3.5,3.5,3.5,3.5,4.5,4.5,4.5,4.5,4.5,4.5]
#     line_styles = ['-','-',":",":","--","--",'-',":","--",'-.','-.']

    
    version = "original"
    if version == "original":
#         corrections = ["percentilenorm","limmacounts","combatcounts","bmc","DCC","clr_pca3counts","clr_pca4counts"]
#         corrections_pretty =  ["Percentile Norm","DCC","ComBat","limma","BMC","Fixed PCA Corr.","Tuned PCA Corr."]
 
#         colors = ["#b800a5","#1ad93d",'#FF9300','#b8ba1c','#fdd0a2',"#72C1FC","#0093FF"]
    
        corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","logCPM","vsd","clr","clr_pca3counts","clr_pca4counts"]
        corrections_pretty =  ["Uncorrected","Percentile Norm","DCC","ComBat","limma","BMC","logCPM","VST","CLR","Fixed PCA Corr.","Tuned PCA Corr."]
        colors = ['#e32f27',"#b800a5","#1ad93d",'#FF9300','#b8ba1c','#fdd0a2',"#9A33FF","#F133FF","#3341FF","#72C1FC","#0093FF"]
        line_widths = [3.5,3.5,3.5,3.5,3.5,4.5,4.5,4.5,4.5,4.5,4.5]
        line_styles = ['-','-',":",":","--","--","-",'-','-',':',':']

    elif version == "alt":
        corrections = ["nocorrection","logcpm_combat" , "logcpm_limma" ,  "logcpm_bmc" ,    "vst_combat"  ,   "vst_limma" ,     "vst_bmc" ,
                                          "rel_clr_combat", "rel_clr_limma", "rel_clr_bmc"]
        corrections_pretty = ["Uncorrected","logCPM + ComBat" , "logCPM + limma" ,  "logCPM + BMC" ,    "VST + ComBat"  ,   "VST + limma" ,     "VST + BMC" ,
                                          "CLR + ComBat", "CLR + limma", "CLR + BMC"]
        
        #corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","clr","vsd","logCPM","clr_pca3counts","clr_pca4counts"]
        #corrections_pretty =  ["Uncorrected","Percentile Norm","DCC","ComBat","limma","BMC","CLR","VST","logCPM","Fixed PCA Corr.","Tuned PCA Corr."]
        colors = ['#e32f27',"#9A33FF","#9A33FF","#9A33FF","#F133FF","#F133FF","#F133FF","#3341FF","#3341FF","#3341FF"]
        line_widths = [3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5]
        line_styles = ['-','-',':','--','-',':','--','-',':','--']
    else:
        corrections = ["nocorrection","logCPM","vsd","clr","logcpm_combat" , "logcpm_limma" ,  "logcpm_bmc" ,    "vst_combat"  ,   "vst_limma" ,     "vst_bmc" ,
                                          "rel_clr_combat", "rel_clr_limma"] #, "rel_clr_bmc"]
        corrections_pretty = ["Uncorrected","logCPM","VST","CLR","logCPM + ComBat" , "logCPM + limma" ,  "logCPM + BMC" ,    "VST + ComBat"  ,   "VST + limma" ,     "VST + BMC" ,
                                          "CLR + ComBat", "CLR + limma", "CLR + BMC"]
        
        #corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","clr","vsd","logCPM","clr_pca3counts","clr_pca4counts"]
        #corrections_pretty =  ["Uncorrected","Percentile Norm","DCC","ComBat","limma","BMC","CLR","VST","logCPM","Fixed PCA Corr.","Tuned PCA Corr."]
        colors = ['#e32f27',"#9A33FF","#F133FF","#3341FF","#9A33FF","#9A33FF","#9A33FF","#F133FF","#F133FF","#F133FF","#3341FF","#3341FF","#3341FF"]
        line_widths = [3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5,3.5]
        line_styles = ['-','-','-','-',':','--','-.',':','--','-.',':','--',"-."]
        
   

    
    
    
    #corrections = ["nocorrection","percentilenorm","DCC","combatcounts","limmacounts","bmc","clr_pca3counts","clr_pca4counts"]
    
    for s in range(len(all_studies)):
        for s2 in range((s+1),len(all_studies)):
            d11 = all_studies[s] # 'HanniganGD_2017'
            d21 = all_studies[s2] #'YuJ_2015'
            d12 = all_studies[s2] #'YuJ_2015'
            d22 = all_studies[s] #'HanniganGD_2017'


            with open(out_dir  + 'titrate_biomarkers_' + d11 + '_' + d21 + '.pkl', 'rb') as handle:
                    titrate1 = pickle.load(handle)            

            with open(out_dir  + 'titrate_biomarkers_' + d12 + '_' + d22 + '.pkl', 'rb') as handle:
                    titrate2 = pickle.load(handle)
            
            #if version == "alt2":
            with open(out_dir2  + 'titrate_biomarkers_' + d11 + '_' + d21 + '.pkl', 'rb') as handle:
                    #titrate1 = pickle.load(handle)    
                    titrate1.update(pickle.load(handle) )

            with open(out_dir2  + 'titrate_biomarkers_' + d12 + '_' + d22 + '.pkl', 'rb') as handle:
                    titrate2.update(pickle.load(handle))
            
            for titr in [1,2]:
                if titr == 1:
                    titrateTemp= titrate1
                else:
                    titrateTemp= titrate2
                    
                plot_titrate_rel_names = dict()
                for correction in corrections:
                    plot_titrate_rel_names[correction] = dict()
                    plot_titrate_rel_names[correction]["fraction"]  = []
                    plot_titrate_rel_names[correction]["num_sig"]  = []
                    for f in fractions:
                        plot_titrate_rel_names[correction]["fraction"].append(f)
                        num_sig = []
                        for n in range(num_replicates):
                            num_sig.append(len(titrateTemp[correction][n][f]))

                        # calculate mean number of significant OTUs
                        plot_titrate_rel_names[correction]["num_sig"].append(np.mean(num_sig))
                
                if titr == 1:
                    titrate1 = plot_titrate_rel_names
                else:
                    titrate2 = plot_titrate_rel_names

            

            #corrections = ["nocorrection","percentilenorm","clr_pcacounts"] 
            #corrections = corrections_copy

            import matplotlib.pyplot as plt

            fig, (ax1,ax2) = plt.subplots(1,2,sharex=True, sharey=True)  

            

            for c in range(len(corrections)):
                ax1.plot(titrate1[corrections[c]]["fraction"],titrate1[corrections[c]]["num_sig"],
                         label = corrections_pretty[c],linewidth=line_widths[c],linestyle = line_styles[c],
                        color = colors[c])
            d1 = d11
            d2 = d21
            ax1.set_title(d1 + ' > titrate ' + d2 ,fontsize=9)

            for c in range(len(corrections)):
                ax2.plot(titrate2[corrections[c]]["fraction"],titrate2[corrections[c]]["num_sig"],
                         label = corrections_pretty[c],linewidth=line_widths[c],linestyle = line_styles[c],
                        color = colors[c])

            d2 = d22
            d1 = d12 
            ax2.set_title(d1 + ' > titrate ' + d2 ,fontsize=9)

            ax1.locator_params(nbins=5, axis='y')
            ax2.legend(loc=2,prop={'size':10})
            #fig.text(0.001, 0.5, 'number of significant OTUs (q <= 0.05)', va='center', rotation='vertical',fontsize=12)
            fig.text(0.5, 0.003, 'fraction of control samples from another study', ha='center',fontsize=12)
            ax1.set_ylabel('number of significant taxa (q <= 0.05)')
            plt.tight_layout()
            #plt.show()

            plt.savefig(out_dir  + 'Cleantitrate_' + d11 + '_' + d21 + '.pdf',dpi=300,format='pdf')

# %%
out_dir2
# Out:
# '/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/Thomasr_complete_otu/titration_archive/'
