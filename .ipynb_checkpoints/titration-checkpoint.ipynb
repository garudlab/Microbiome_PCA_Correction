# %%
import sys
import pandas as pd
import numpy as np
import random
from collections import Counter
import scipy as sp
from scipy import stats, optimize, interpolate
import statsmodels.api as sm
import statsmodels as sm
random.seed(0)
from functools import reduce
import os
import pickle

# %%
main_dir ="/u/home/b/briscoel/project-halperin/MicroBatch/data/"
script_folder= "/u/home/b/briscoel/project-halperin/MicroBatch/RevisionSequence/"
local = True

sys.argv = [ "Gibbonsr_complete_otu","rel",""]

if local:
    main_dir = "/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/"
    script_folder = "/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/RevisionSequence/"

folder = sys.argv[0] # "AGPr_max_k5" #"AGPr_complete_otu" 
trans = sys.argv[1] #"rel"

data_dir = main_dir + folder + "/"


out_dir = data_dir + "titration/"
if not os.path.isdir(out_dir):
    os.makedirs(out_dir)
    print("created folder : ", out_dir)

else:
    print(out_dir, "folder already exists.")
# Out:
# /Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/Gibbonsr_complete_otu/titration/ folder already exists.

# %%
metadata_table = pd.read_csv(data_dir + "metadata.txt", delimiter = "\t",header=0)



if folder == "Gibbonsr_complete_otu":
    phenotype ='bin_crc_normal'
    batch="study"
    metadata_table[phenotype] = [1 if lab=='CRC' else 0 for lab in metadata_table['bin_crc_normal']]
elif folder == "Thomasr_complete_otu":
    phenotype ='bin_crc_normal'
    batch="dataset_name"
all_studies = list(Counter(metadata_table[batch]))

# %%
#all_control_samples = list(metadata_table[metadata_table['bin_crc_normal'] == 0].index)
#all_case_samples = list(metadata_table[metadata_table['bin_crc_normal'] == 1].index)
#feature_table_presence = feature_table  > 0  
# control_presence_proportion = (feature_table_presence[all_control_samples].sum(axis =1))/len(all_control_samples)
# case_presence_proportion = (feature_table_presence[all_case_samples].sum(axis =1))/len(all_case_samples)
# ## FILTER FOR 1/3 in at least case OR control : not using for now
# prevalence_filter = np.array(control_presence_proportion > 0.33) | np.array(case_presence_proportion > 0.33)

# %%
orig_feature_table = pd.read_csv(data_dir  +"feature_table_" + trans + ".txt" ,delimiter = "\t",header=0)
df_biomarkers = pd.DataFrame(index = orig_feature_table.index,columns = all_studies)

# %%
def titration(d1, d2 ,metadata_table,fractions,corrections):
    random.seed(0)
    control_metadata1 = metadata_table[(metadata_table[phenotype] == 0 ) & (metadata_table[batch] ==  d1) ]
    case_metadata1 = metadata_table[(metadata_table[phenotype] == 1) & (metadata_table[batch] ==  d1)]

    control_metadata2 = metadata_table[(metadata_table[phenotype] == 0 ) & (metadata_table[batch] ==  d2) ]
    case_metadata2 = metadata_table[(metadata_table[phenotype] == 1) & (metadata_table[batch] ==  d2)]

    control_samples_d1 = list(control_metadata1.index)
    case_samples_d1 = list(case_metadata1.index)

    control_samples_d2 = list(control_metadata2.index)
    case_samples_d2 = list(case_metadata2.index)

    min_sample_size = min([len(control_samples_d1),len(case_samples_d1),len(control_samples_d2),len(case_samples_d2)])
    
    control_samples_d1 = random.sample(control_samples_d1,min_sample_size)
    case_samples_d1 = random.sample(case_samples_d1,min_sample_size)
    control_samples_d2 = random.sample(control_samples_d2,min_sample_size)
    case_samples_d2 = random.sample(case_samples_d2,min_sample_size)
    
    
    replicate_titrate_rel_names = {}
    replicate_titrate_rel_fdr = {}



    
    for correction in corrections:
        print(correction)
        replicate_titrate_rel_names[correction] = dict()
        replicate_titrate_rel_fdr[correction] = dict()
        if correction == "nocorrection":
            feature_table = pd.read_csv(data_dir  + "feature_table_" + trans + ".txt" ,delimiter = "\t",header=0)
        else:
            feature_table = pd.read_csv(data_dir  +"feature_table_" + trans + "_" + correction + ".txt" ,delimiter = "\t",header=0)

        for n in range(num_replicates):
            print(n)
            titrate_rel_names = {}
            titrate_rel_fdr = {}
            for f in fractions:
                pvals = []           
                case_samples = case_samples_d1
                control_samples = random.sample(control_samples_d1,int((1-f) * min_sample_size)) + random.sample(control_samples_d2, int(f * min_sample_size))
                feature_table_titrate_control = feature_table[control_samples ]
                feature_table_titrate_case = feature_table[case_samples ]
                
                feature_table_titrate_control_prev = (feature_table_titrate_control > 1e-4)
                feature_table_titrate_case_prev = (feature_table_titrate_case > 1e-4)

                # for each taxa
                tax_names = []
                for tax in range(feature_table_titrate_case.shape[0]):
                    
                    if feature_table_titrate_control_prev.iloc[tax,:].astype(bool).sum()/float(feature_table_titrate_control.shape[1]) >= 1/3.0 or feature_table_titrate_case_prev.iloc[tax,:].astype(bool).sum()/float(feature_table_titrate_case.shape[1]) >= 1/3.0:
                        pvals.append(sp.stats.ranksums(feature_table_titrate_control.iloc[tax,:],feature_table_titrate_case.iloc[tax,:])[1])
                        tax_names.append(feature_table_titrate_case.index[tax])
                    #else:
                        #pvals.append(1)
#                     if (feature_table_titrate_control.iloc[tax,:] > -2).astype(bool).sum()/float(feature_table_titrate_control.shape[1]) >= 1/3.0 or (feature_table_titrate_case.iloc[tax,:] > -2).astype(bool).sum()/float(feature_table_titrate_case.shape[1]) >= 1/3.0:
#                         pvals.append(sp.stats.ranksums(feature_table_titrate_control.iloc[tax,:],feature_table_titrate_case.iloc[tax,:])[1])
#                     else:
#                         pvals.append(1)

                pvals = np.array(pvals)
                if(len(pvals) > 0):
    
                    pvals_fdr = sm.sandbox.stats.multicomp.multipletests(np.array(pvals),alpha=0.05,method='fdr_bh')[1]
                else:
                    pvals_fdr = []
                names = []
                fdr = []

                for j in range(len(pvals_fdr)):
                    if pvals_fdr[j] <= 0.05:
                        names.append(tax_names[j])
                        fdr.append(pvals_fdr[j])


                titrate_rel_names[f] = names
                titrate_rel_fdr[f] = fdr



            replicate_titrate_rel_names[correction][n] = titrate_rel_names
            replicate_titrate_rel_fdr[correction][n] = titrate_rel_fdr
            
    plot_titrate_rel_names = dict()
    for correction in corrections:
        plot_titrate_rel_names[correction] = dict()
        plot_titrate_rel_names[correction]["fraction"]  = []
        plot_titrate_rel_names[correction]["num_sig"]  = []
        for f in fractions:
            plot_titrate_rel_names[correction]["fraction"].append(f)
            num_sig = []
            for n in range(num_replicates):
                num_sig.append(len(replicate_titrate_rel_fdr[correction][n][f]))

            # calculate mean number of significant OTUs
            plot_titrate_rel_names[correction]["num_sig"].append(np.mean(num_sig))
    return(plot_titrate_rel_names,replicate_titrate_rel_names)

# %%
# 
# fractions = [0,.25 ,  1] # fraction of controls replaced
# corrections = ["nocorrection","percentilenorm"] 
# titrate1,biomarkers1 = titration(d1 = d11, d2 = d21, 
#                                    metadata_table = metadata_table,fractions = fractions,corrections = corrections)

# %%
num_replicates= 5

fractions = [0,.25 , .50, 0.75, 1] # fraction of controls replaced
corrections = ["nocorrection","percentilenorm","limmacounts","combatcounts","bmc","DCC","clr_pca3counts","clr_pca1counts"] #,] 
corrections_copy = corrections


for s in range(len(all_studies)):
    for s2 in range((s+1),len(all_studies)):
        d11 = all_studies[s] # 'HanniganGD_2017'
        d21 = all_studies[s2] #'YuJ_2015'
        d12 = all_studies[s2] #'YuJ_2015'
        d22 = all_studies[s] #'HanniganGD_2017'

        
        titrate1,biomarkers1 = titration(d1 = d11, d2 = d21, 
                                   metadata_table = metadata_table,fractions = fractions,corrections = corrections)
        
#         biomarker_list_list = []
#         for i in range(num_replicates):
#             biomarker_list_list.append(biomarkers1["clr_pcacounts"][i][0])

#         agreement_onedataset = list(reduce(set.intersection, [set(item) for item in biomarker_list_list ]))
#         df_biomarkers.loc[agreement_onedataset,d11] = 1
        
#         df_biomarkers.to_csv( "DF_biomarkers.csv",index=True)
        
#         print("starting titrate 2")

        titrate2,biomarkers2 = titration(d1 = d12 , d2 = d22, 
                                   metadata_table = metadata_table,fractions = fractions,corrections = corrections)
        
        
        ## SAVE TO PICKLE
        print("Saving pickles")
        with open(out_dir  + 'titrate_' + d11 + '_' + d21 + '.pkl', 'wb') as handle:
            pickle.dump(titrate1, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with open(out_dir  + 'titrate_' + d12 + '_' + d22 + '.pkl', 'wb') as handle:
            pickle.dump(titrate2, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with open(out_dir  + 'titrate_biomarkers_' + d11 + '_' + d21 + '.pkl', 'wb') as handle:
            pickle.dump(biomarkers1, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with open(out_dir  + 'titrate_biomarkers_' + d12 + '_' + d22 + '.pkl', 'wb') as handle:
            pickle.dump(biomarkers2, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
        
        #corrections = ["nocorrection","percentilenorm","clr_pcacounts"] 
        corrections = corrections_copy

        import matplotlib.pyplot as plt

        fig, (ax1,ax2) = plt.subplots(1,2,sharex=True, sharey=True)  

        line_widths = [3.5,3.5,3.5,3.5,3.5,4.5,4.5,4.5]
        line_styles = ['-','-',":",":","--","--",'-.','-.']

        for c in range(len(corrections)):
            ax1.plot(titrate1[corrections[c]]["fraction"],titrate1[corrections[c]]["num_sig"],
                     label = corrections[c],linewidth=line_widths[c],linestyle = line_styles[c])
        d1 = d11
        d2 = d21
        ax1.set_title(d1 + ' > titrate ' + d2 ,fontsize=9)

        for c in range(len(corrections)):
            ax2.plot(titrate2[corrections[c]]["fraction"],titrate2[corrections[c]]["num_sig"],
                     label = corrections[c],linewidth=line_widths[c],linestyle = line_styles[c])

        d2 = d22
        d1 = d12 
        ax2.set_title(d1 + ' > titrate ' + d2 ,fontsize=9)

        ax1.locator_params(nbins=5, axis='y')
        ax2.legend(loc=2,prop={'size':10})
        #fig.text(0.001, 0.5, 'number of significant OTUs (q <= 0.05)', va='center', rotation='vertical',fontsize=12)
        fig.text(0.5, 0.003, 'fraction of control samples from another study', ha='center',fontsize=12)
        ax1.set_ylabel('number of significant OTUs (q <= 0.05)')
        plt.tight_layout()
        #plt.show()
        
        plt.savefig(out_dir  + 'titrate_' + d11 + '_' + d21 + '.pdf',dpi=300,format='pdf')
# Out:
# nocorrection
# 0
# 1
# 2
# 3
# 4
# percentilenorm
# 0
# 1
# 2
# 3
# 4
# limmacounts
# 0
# 1
# 2
# 3
# 4
# combatcounts
# 0
# 1
# 2
# 3
# 4
# bmc
# 0
# 1
# 2
# 3
# 4
# DCC
# 0
# 1
# 2
# 3
# 4
# clr_pca3counts
# 0
# 1
# 2
# 3
# 4
# clr_pca1counts
# 0
# 1
# 2
# 3
# 4
# nocorrection
# 0
# 1
# 2
# 3
# 4
# percentilenorm
# 0
# 1
# 2
# 3
# 4
# limmacounts
# 0
# 1
# 2
# 3
# 4
# combatcounts
# 0
# 1
# 2
# 3
# 4
# bmc
# 0
# 1
# 2
# 3
# 4
# DCC
# 0
# 1
# 2
# 3
# 4
# clr_pca3counts
# 0
# 1
# 2
# 3
# 4
# clr_pca1counts
# 0
# 1
# 2
# 3
# 4
# Saving pickles
# nocorrection
# 0
# 1
# 2
# 3
# 4
# percentilenorm
# 0
# 1
# 2
# 3
# 4
# limmacounts
# 0
# 1
# 2
# 3
# 4
# combatcounts
# 0
# 1
# 2
# 3
# 4
# bmc
# 0
# 1
# 2
# 3
# 4
# DCC
# 0
# 1
# 2
# 3
# 4
# clr_pca3counts
# 0
# 1
# 2
# 3
# 4
# clr_pca1counts
# 0
# 1
# 2
# 3
# 4
# nocorrection
# 0
# 1
# 2
# 3
# 4
# percentilenorm
# 0
# 1
# 2
# 3
# 4
# limmacounts
# 0
# 1
# 2
# 3
# 4
# combatcounts
# 0
# 1
# 2
# 3
# 4
# bmc
# 0
# 1
# 2
# 3
# 4
# DCC
# 0
# 1
# 2
# 3
# 4
# clr_pca3counts
# 0
# 1
# 2
# 3
# 4
# clr_pca1counts
# 0
# 1
# 2
# 3
# 4
# Saving pickles
# nocorrection
# 0
# 1
# 2
# 3
# 4
# percentilenorm
# 0
# 1
# 2
# 3
# 4
# limmacounts
# 0
# 1
# 2
# 3
# 4
# combatcounts
# 0
# 1
# 2
# 3
# 4
# bmc
# 0
# 1
# 2
# 3
# 4
# DCC
# 0
# 1
# 2
# 3
# 4
# clr_pca3counts
# 0
# 1
# 2
# 3
# 4
# clr_pca1counts
# 0
# 1
# 2
# 3
# 4
# nocorrection
# 0
# 1
# 2
# 3
# 4
# percentilenorm
# 0
# 1
# 2
# 3
# 4
# limmacounts
# 0
# 1
# 2
# 3
# 4
# combatcounts
# 0
# 1
# 2
# 3
# 4
# bmc
# 0
# 1
# 2
# 3
# 4
# DCC
# 0
# 1
# 2
# 3
# 4
# clr_pca3counts
# 0
# 1
# 2
# 3
# 4
# clr_pca1counts
# 0
# 1
# 2
# 3
# 4
# Saving pickles

# %%
print(all_studies)
for s in range(len(all_studies)):
    for s2 in range((s+1),len(all_studies)):
        print(all_studies[s] + " " + all_studies[s2])
        print(all_studies[s2] + " " + all_studies[s])
# Out:
# ['crc_baxter', 'crc_zackular', 'crc_zeller']
# crc_baxter crc_zackular
# crc_zackular crc_baxter
# crc_baxter crc_zeller
# crc_zeller crc_baxter
# crc_zackular crc_zeller
# crc_zeller crc_zackular

# %%
 with open(out_dir  + 'titrate_biomarkers_' + d12 + '_' + d22 + '..pickle', 'rb') as handle:
        test = pickle.load(handle)

# %%
test
# Out:
# {'nocorrection': {0: {0: ['k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Peptostreptococcaceae;g__Peptostreptococcus;s__;d__denovo279'],
#    1: ['k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1778',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1779',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1516',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1511',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1519',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1532',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1735',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1885',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Prevotellaceae;g__Paraprevotella;s__;d__denovo129',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo465',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1714',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo106',
#     'k__Bacteria;p__Proteobacteria;c__Deltaproteobacteria;o__Desulfovibrionales;f__Desulfovibrionaceae;g__Bilophila;s__;d__denovo104',
#     'k__Bacteria;p__Firmicutes;c__Negativicutes;o__Selenomonadales;f__Acidaminococcaceae;g__Acidaminococcus;s__;d__denovo96',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Blautia;s__;d__denovo3',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1594',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__;g__;s__;d__denovo341',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo342',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo349',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo161',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVb;s__;d__denovo160',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo2038',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Faecalibacterium;s__;d__denovo919',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo369',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo148',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo142',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1800',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1803',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo308',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo303',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1682',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1683',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1689',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo238',
#     'k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Coriobacteriales;f__Coriobacteriaceae;g__;s__;d__denovo518',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo512',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo704',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo288',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Blautia;s__;d__denovo287',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo283',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1645',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1648',
#     'k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Coriobacteriales;f__Coriobacteriaceae;g__;s__;d__denovo269',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1919',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo741',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__;s__;d__denovo1056',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__;g__;s__;d__denovo243',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1600',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__;g__;s__;d__denovo63',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__;g__;s__;d__denovo66',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo763',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo1028',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo226',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1488',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo45',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__;d__denovo44',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo48',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo202',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo24',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Lachnospiracea_incertae_sedis;s__;d__denovo29',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo2054',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1206',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__;f__;g__;s__;d__denovo410',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo414',
#     'k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Streptococcus;s__;d__denovo418',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo628',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Ruminococcus;s__;d__denovo122',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__;d__denovo459',
#     'k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o__Erysipelotrichales;f__Erysipelotrichaceae;g__Holdemania;s__;d__denovo455',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1890',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1747',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1525',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1521',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiales_Incertae_Sedis_XIII;g__Mogibacterium;s__;d__denovo668',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo476',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__;d__denovo394',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiaceae_1;g__Clostridium_sensu_stricto;s__;d__denovo390',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Sporobacter;s__;d__denovo85',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo84',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo81',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo80',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Oscillibacter;s__;d__denovo89',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Coprococcus;s__;d__denovo88',
#     'k__Bacteria;p__Proteobacteria;c__Deltaproteobacteria;o__Desulfovibrionales;f__;g__;s__;d__denovo568',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1852',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1854',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1323',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Pseudoflavonifractor;s__;d__denovo355',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo358',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Prevotellaceae;g__Paraprevotella;s__;d__denovo172',
#     'k__Bacteria;p__Firmicutes;c__Erysipelotrichia;o__Erysipelotrichales;f__Erysipelotrichaceae;g__Clostridium_XVIII;s__;d__denovo178',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__;g__;s__;d__denovo541',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__;s__;d__denovo371',
#     'k__Bacteria;p__Proteobacteria;c__Deltaproteobacteria;o__Desulfovibrionales;f__Desulfovibrionaceae;g__Desulfovibrio;s__;d__denovo158',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1815',
#     'k__Bacteria;p__Cyanobacteria/Chloroplast;c__Chloroplast;o__;f__Chloroplast;g__Streptophyta;s__;d__denovo315',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1875',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1701',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1690',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiales_Incertae_Sedis_XI;g__Parvimonas;s__;d__denovo333',
#     'k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales;f__Staphylococcaceae;g__Staphylococcus;s__;d__denovo199',
#     'k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Coriobacteriales;f__Coriobacteriaceae;g__Eggerthella;s__;d__denovo192',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Oribacterium;s__;d__denovo194',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Sporobacter;s__;d__denovo195',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Clostridium_IV;s__;d__denovo299',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo291',
#     'k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Actinomycetales;f__Actinomycetaceae;g__Actinomyces;s__;d__denovo296',
#     'k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacteriales;f__Enterobacteriaceae;g__Escherichia/Shigella;s__;d__denovo1063',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo273',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Robinsoniella;s__;d__denovo274',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Peptostreptococcaceae;g__Peptostreptococcus;s__;d__denovo279',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiales_Incertae_Sedis_XIII;g__;s__;d__denovo278',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1651',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1387',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Bacteroidaceae;g__Bacteroides;s__;d__denovo737',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Roseburia;s__;d__denovo6',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Clostridium_XlVa;s__;d__denovo256',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Flavonifractor;s__;d__denovo254',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo252',
#     'k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o__Fusobacteriales;f__Fusobacteriaceae;g__Fusobacterium;s__;d__denovo251',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__;g__;s__;d__denovo259',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1670',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1454',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__;s__;d__denovo71',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__;g__;s__;d__denovo72',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo74',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Lachnospiracea_incertae_sedis;s__;d__denovo75',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Blautia;s__;d__denovo76',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo77',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Porphyromonadaceae;g__;s__;d__denovo239',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__;s__;d__denovo230',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1613',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Coprococcus;s__;d__denovo55',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1558',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1559',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__;f__;g__;s__;d__denovo217',
#     'k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Coriobacteriales;f__Coriobacteriaceae;g__Collinsella;s__;d__denovo37',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Blautia;s__;d__denovo30',
#     'k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhodobacterales;f__Rhodobacteraceae;g__Paracoccus;s__;d__denovo38',
#     'k__Bacteria;p__;c__;o__;f__;g__;s__;d__denovo1497',
#     'k__;p__;c__;o__;f__;g__;s__;d__denovo1495',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Ruminococcaceae;g__Ruminococcus;s__;d__denovo630',
#     'k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Streptococcus;s__;d__denovo18',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Anaerostipes;s__;d__denovo12',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__Blautia;s__;d__denovo11',
#     'k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Lachnospiraceae;g__;s__;d__denovo17',
#     'k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Sphingomonadales;f__Sphingomonadaceae;g__Sphingomonas;s__;d__denovo14',
#     'k__Bacteria;p__Bacteroidetes;c__Bacteroidia;o__Bacteroidales;f__Prevotellaceae;g__Prevotella;s__;d__denovo15',
#     'k__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Pseudomonadales;f__Pseudomonadaceae;g__Pseudomonas;s__;d__denovo404']}}}
